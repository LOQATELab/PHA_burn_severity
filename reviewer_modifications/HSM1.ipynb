# %%
import geopandas as gpd
import xarray as xr
import numpy as np
import rioxarray as rxr
import os
from math import e
import matplotlib.pyplot as plt
import pandas as pd
import rasterio as rio

# %%
Input = r'/Volumes/PhD/imagery/masters/hyper/HSM1/17346_hppp_24mmhr.tif'
Minput = r'/Volumes/PhD/imagery/masters/output/MSM1/17346_MSM1_24mmhr.tif'
h_image = rxr.open_rasterio(Input)
m_image = rxr.open_rasterio(Minput)
h_image.plot()

# %%
m_image.plot()

# %%
b_data = pd.read_csv(r'/Volumes/PhD/imagery/masters/hyper/basins.csv')
b_data
# Out:
#    BASIN_ID  Mean_dNBR  Med_dNBR   PF_dNBR        X1        X3
# 0     17346   0.562744  0.678311  0.786640  0.560555  0.131622
# 1     19384   0.631775  0.665531  0.701887  0.683425  0.139364
# 2     19451   0.638890  0.654705  0.655092  0.243529  0.130000
# 3     21224   0.365260  0.429648  0.682649  0.231744  0.203875
