# %%
# LOAD PACKAGES

import matplotlib.pyplot as plt
import numpy as np
from numpy import asarray
import rioxarray as rxr
import geopandas as gpd
import xarray as xr
import pandas as pd
import glob
import seaborn as sns
import os
import fnmatch
import math
from math import e
from osgeo import gdal 
print("packages loaded")
# Out:
# packages loaded

# %%
# SET DIRECTORIES

# Set basin directory
basins_P_pv = '/mnt/nfs/lss/meerdink/home/skzebarth/masters/basin_data/basin_pixel_values/'
print(sorted(os.listdir(basins_P_pv)))

# Set basin directory
basins = '/mnt/nfs/lss/meerdink/home/skzebarth/masters/output/'
print(sorted(os.listdir(basins)))

out = '/mnt/nfs/lss/meerdink/home/skzebarth/masters/outputpng/'
# Out:
# ['12042_prob_pv.tif', '12057_prob_pv.tif', '12518_prob_pv.tif', '12524_prob_pv.tif', '12527_prob_pv.tif', '12616_prob_pv.tif', '12860_prob_pv.tif', '12997_prob_pv.tif', '13281_prob_pv.tif', '17346_prob_pv.tif', '17347_prob_pv.tif', '17987_prob_pv.tif', '19165_prob_pv.tif', '19167_prob_pv.tif', '19381_prob_pv.tif', '19384_prob_pv.tif', '19450_prob_pv.tif', '19451_prob_pv.tif', '19510_prob_pv.tif', '19512_prob_pv.tif', '19629_prob_pv.tif', '19632_prob_pv.tif', '19647_prob_pv.tif', '19649_prob_pv.tif', '19777_prob_pv.tif', '20029_prob_pv.tif', '20031_prob_pv.tif', '20253_prob_pv.tif', '20254_prob_pv.tif', '20303_prob_pv.tif', '20308_prob_pv.tif', '20384_prob_pv.tif', '20386_prob_pv.tif', '20499_prob_pv.tif', '20504_prob_pv.tif', '20650_prob_pv.tif', '20729_prob_pv.tif', '20734_prob_pv.tif', '21009_prob_pv.tif', '21078_prob_pv.tif', '21083_prob_pv.tif', '21224_prob_pv.tif', '21500_prob_pv.tif', '21513_prob_pv.tif', '21634_prob_pv.tif', '22075_prob_pv.tif', '22668_prob_pv.tif']
# ['.png', '12042_dnbr.tif', '12042_rgb.png', '12057_dnbr.tif', '12057_rgb.png', '12518_dnbr.tif', '12518_rgb.png', '12524_dnbr.tif', '12524_rgb.png', '12527_dnbr.tif', '12527_rgb.png', '12616_dnbr.tif', '12616_rgb.png', '12860_dnbr.tif', '12860_rgb.png', '12997_dnbr.tif', '12997_rgb.png', '13281_dnbr.tif', '13281_rgb.png', '17346_dnbr.tif', '17346_rgb.png', '17347_dnbr.tif', '17347_rgb.png', '17987_dnbr.tif', '17987_rgb.png', '19165_dnbr.tif', '19165_rgb.png', '19167_dnbr.tif', '19167_rgb.png', '19381_dnbr.tif', '19381_rgb.png', '19384_dnbr.tif', '19384_rgb.png', '19450_dnbr.tif', '19450_rgb.png', '19451_dnbr.tif', '19451_rgb.png', '19510_dnbr.tif', '19510_rgb.png', '19512_dnbr.tif', '19512_rgb.png', '19629_dnbr.tif', '19629_rgb.png', '19632_dnbr.tif', '19632_rgb.png', '19647_dnbr.tif', '19647_rgb.png', '19649_dnbr.tif', '19649_rgb.png', '19777_dnbr.tif', '19777_rgb.png', '20029_dnbr.tif', '20029_rgb.png', '20031_dnbr.tif', '20031_rgb.png', '20253_dnbr.tif', '20253_rgb.png', '20254_dnbr.tif', '20254_rgb.png', '20303_dnbr.tif', '20303_rgb.png', '20308_dnbr.tif', '20308_rgb.png', '20384_dnbr.tif', '20384_rgb.png', '20386_dnbr.tif', '20386_rgb.png', '20499_dnbr.tif', '20499_rgb.png', '20504_dnbr.tif', '20504_rgb.png', '20650_dnbr.tif', '20650_rgb.png', '20729_dnbr.tif', '20729_rgb.png', '20734_dnbr.tif', '20734_rgb.png', '21009_dnbr.tif', '21009_rgb.png', '21078_dnbr.tif', '21078_rgb.png', '21083_dnbr.tif', '21083_rgb.png', '21224_dnbr.tif', '21224_rgb.png', '21500_dnbr.tif', '21500_rgb.png', '21513_dnbr.tif', '21513_rgb.png', '21634_dnbr.tif', '21634_rgb.png', '22075_dnbr.tif', '22075_rgb.png', '22668_dnbr.tif', '22668_rgb.png', 'pre-fire.png']

# %%
# OPEN AND DISPLAY PER PIXEL PROBABILITY RASTERS
for filename in sorted(os.listdir(basins_P_pv)):
    f = os.path.join(basins_P_pv, filename)
    if filename.endswith('_prob_pv.tif'):
        # Set basin naming
        b_name = filename.split('_')
        b_name_int = b_name[0]
        
        prob = rxr.open_rasterio(f)
        a = np.mean(prob)
        prob.plot(
            cmap = 'gnuplot'
        )
        plt.title(f"Basin {b_name_int} Likelihood | Basin avg: {a:.3g}")
        #plt.title('Basin ' + b_name_int + ' pixel prediction')
        plt.axis('off')
        plt.savefig(os.path.join(out, b_name_int + '_ppp.png'))
        plt.close()
        plt.show()

# %%
for filename in sorted(os.listdir(basins)):
    f = os.path.join(basins, filename)
    if filename.endswith('.tif'):
        b_name = filename.split('_')
        b_name_int = b_name[0]
        dnbr = rxr.open_rasterio(f)
        x2 = np.mean(dnbr)
        dnbr.plot(
            cmap = 'gray'
        )
        plt.title(f"Basin {b_name_int} dNBR Values | Basin X2: {x2:.3g}")
        #plt.title('Basin ' + b_name_int + ' dnbr values, ' + 'x2: ' + str())
        plt.axis('off')
        plt.savefig(os.path.join(out, b_name_int + '_bdnbr.png'))
        plt.close()
        plt.show()

# %%
for filename in sorted(os.listdir(basins)):
    f = os.path.join(basins, filename)
    if filename.endswith('rgb.png'):
        b_name = filename.split('.')
        b_name_int = b_name[0]
        img = plt.imread(f)
        plt.imshow(img)
        plt.axis('off')
        plt.title(b_name_int)
        plt.show()

# %%
for filename in sorted(os.listdir(basins_P_pv)):
    f = os.path.join(basins_P_pv, filename)
    if filename.endswith('_prob_pv.tif'):
        # Set basin naming
        b_name = filename.split('_')
        b_name_int = b_name[0]
        
        prob = rxr.open_rasterio(f)
        a = np.mean(prob)
        f, ax = plt.subplots(figsize=(10, 6))
        prob.plot.hist(ax=ax,
                       color="purple",
                       bins = 50)
        ax.set(title= f" Basin {b_name_int} Distribution of Per Pixel Initiation Values",
        xlabel='Pixel Initiation Likelihood',
        ylabel='Frequency')
        plt.show()
